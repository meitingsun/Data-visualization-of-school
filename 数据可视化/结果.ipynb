# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
#index=np.arange(5)
#values=[2.73,6.83,5.90,4.58,4.34]
#legend=['IMGA-DBN','DMMHC','GS','MWST-HC','MWST-GES']
#plt.bar(index,values)

width=0.1 #设置柱与柱之间的宽度
plt.bar(1,2.73,width*10,color='black',label='IMGA-DBN')
plt.bar(2,6.83,width*10,color='Gainsboro',label='DMMHC')
plt.bar(3,5.90,width*10,color='Silver',label='GS')
plt.bar(4,4.58,width*10,color='Gray',label='MWST-HC')
plt.bar(5,4.34,width*10,color='DimGray',label='MWST-GES')
plt.legend(bbox_to_anchor=(0.7, 0.60),fontsize= 14)  # 让图例生效
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('5种算法',fontsize= 12) #X轴标签
plt.ylabel("先验网汉明距离",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\water_chushi.jpg',dpi = 100)

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
#index=np.arange(5)
#values=[2.73,6.83,5.90,4.58,4.34]
#legend=['IMGA-DBN','DMMHC','GS','MWST-HC','MWST-GES']
#plt.bar(index,values)

width=0.1 #设置柱与柱之间的宽度
plt.bar(1,5.09,width*10,color='black',label='IMGA-DBN')
plt.bar(2,7.31,width*10,color='Gainsboro',label='DMMHC')
plt.bar(3,9.74,width*10,color='Silver',label='GS')
plt.bar(4,7.98,width*10,color='Gray',label='MWST-HC')
plt.bar(5,6.42,width*10,color='DimGray',label='MWST-GES')
plt.legend(bbox_to_anchor=(0.7,0.61),fontsize= 14)  # 让图例生效
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('5种算法',fontsize= 12) #X轴标签
plt.ylabel("转移网汉明距离",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\water_zhuanyi.jpg',dpi = 100)

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
#index=np.arange(5)
#values=[2.73,6.83,5.90,4.58,4.34]
#legend=['IMGA-DBN','DMMHC','GS','MWST-HC','MWST-GES']
#plt.bar(index,values)

width=0.1 #设置柱与柱之间的宽度
plt.bar(1,230.40,width*10,color='black',label='IMGA-DBN')
plt.bar(2,378.97,width*10,color='Gainsboro',label='DMMHC')
plt.bar(3,493.19,width*10,color='Silver',label='GS')
plt.bar(4,367.77,width*10,color='Gray',label='MWST-HC')
plt.bar(5,316.53,width*10,color='DimGray',label='MWST-GES')
plt.legend(bbox_to_anchor=(0.7,0.61),fontsize= 14)  # 让图例生效
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('5种算法',fontsize= 12) #X轴标签
plt.ylabel("迭代次数",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\water_迭代.jpg',dpi = 100)

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
#index=np.arange(5)
#values=[2.73,6.83,5.90,4.58,4.34]
#legend=['IMGA-DBN','DMMHC','GS','MWST-HC','MWST-GES']
#plt.bar(index,values)
error_params=dict(elinewidth=3,ecolor='black',capsize=4)#设置误差标记参数
width=0.1 #设置柱与柱之间的宽度
plt.bar(1,158.48,width*10,color='black',label='IMGA-DBN',yerr=10.99,error_kw=error_params)
plt.bar(2,294.24,width*10,color='Gainsboro',label='DMMHC',yerr=18.67,error_kw=error_params)
plt.bar(3,430.01,width*10,color='Silver',label='GS',yerr=69.13,error_kw=error_params)
plt.bar(4,347.9,width*10,color='Gray',label='MWST-HC',yerr=14.83,error_kw=error_params)
plt.bar(5,309.3,width*10,color='DimGray',label='MWST-GES',yerr=15.94,error_kw=error_params)
plt.legend(bbox_to_anchor=(0.7,0.61),fontsize= 14)  # 让图例生效
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('5种算法',fontsize= 12) #X轴标签
plt.ylabel("运行时间",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\water_shijian.jpg',dpi = 100)

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
# 先验网准确度
l=range(0,12000,1000)
x=(1000,2500,5000,10000)
y_EMGA=[2.3,2.0,1.1,0.6]
y_DMMHC=[6.5,6.3,5.4,4.5]
y_GS=[6.0,5.3,4.3,2.2]
plt.plot(x, y_EMGA, marker='o',color='black',label='IMGA-DBN')
plt.plot(x, y_DMMHC, marker='*',color='black',ls='-.',label='DMMHC')
plt.plot(x, y_GS, marker='+',color='black',ls='--',label='GS')
plt.legend(fontsize= 14)  # 让图例生效
plt.xticks(l,rotation=1)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.margins(0)
plt.subplots_adjust(bottom=0.10)
plt.xlabel('样本量',fontsize= 12) #X轴标签
plt.ylabel("先验网汉明距离",fontsize= 12) #Y轴标签
# plt.title("A simple plot") #标题
plt.savefig('D:\Entertainment\jyputer\chushi.jpg',dpi = 100)

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
# 转移网准确度
l=range(0,12000,1000)
x=(1000,2500,5000,10000)
y_EMGA=[4.0,3.5,3.5,3.0]
y_DMMHC=[6.5,6.0,7.7,6.0]
y_GS=[11,9.0,6.0,5.5]
plt.plot(x, y_EMGA, marker='o',color='black',label='IMGA-DBN')
plt.plot(x, y_DMMHC, marker='*',color='black',ls='-.',label='DMMHC')
plt.plot(x, y_GS, marker='+',color='black',ls='--',label='GS')
plt.legend(fontsize= 14)  # 让图例生效
plt.xticks(l,rotation=1)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.margins(0)
plt.subplots_adjust(bottom=0.10)
plt.xlabel('样本量',fontsize= 12) #X轴标签
plt.ylabel("转移网汉明距离",fontsize= 12) #Y轴标签
# plt.title("A simple plot") #标题
plt.savefig('D:\Entertainment\jyputer\zhuanyi.jpg',dpi = 900)

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
x=[0,15,35,40,55,
   60,65,70,75,
   80,85,90,95,100,
   110,120,130,140,150,
   160,170,180,190,200,
   230,250, 270,300,320,350,370,400]
y_EMGA=[-4770,-3803,-3399,-3113,-2940,
        -2798,-2783,-2736,-2709,
        -2695,-2690,-2689,-2687,-2688,
        -2689,-2686,-2688,-2685,-2686,
        -2689,-2686,-2688,-2685,-2686,
        -2689,-2686,-2688,-2685,-2686,-2685,-2686,-2688]
y_MMHC=[-5000,-4873,-4583,-4472,-4378,
        -4323,-4287,-4255,-4163,
        -4137,-4107,-4079,-4047,-4025,
        -4012,-4006,-3995,-3990,-3989,
        -3980,-3982, -3970,-3958,-3920,
        -3898,-3889, -3884,-3881,-3885,-3880,-3881,-3880]

y_GS=  [-4789,-4031,-3673,-3401,-3294,
        -3057,-2999,-2986,-2974,
        -2969,-2960,-2957,-2947,-2940,
        -2930,-2918,-2904,-2893,-2887,
        -2869, -2853,-2844,-2825,-2820,
        -2810,-2803,-2798,-2799,-2798,-2799,-2799,-2798]

y_HC= [-4779,-3931,-3408,-3245,-3088,
       -2968,-2943,-2929,-2898,
       -2888,-2867,-2845,-2820,-2800,
       -2799,-2796,-2755,-2747,-2741,
       -2737,-2728,-2736,-2727,-2738,
       -2737,-2728,-2736,-2727,-2738,-2736,-2727,-2738]


y_GES=[-4840,-4003,-3388,-3298,-3201,
       -3077,-2987,-2947,-2922,
       -2917,-2900,-2888,-2867,-2850,
       -2838,-2811,-2803,-2795,-2763,
       -2754,-2747,-2731,-2729,-2707,
      -2692,-2693,-2693,-2693,-2694,-2692,-2693,-2693,]

plt.plot(x, y_EMGA,'black',label='IMGA-DBN',linewidth=4)
plt.plot(x,y_MMHC,"Gainsboro",marker='|',label='DMMHC',linewidth=3)
plt.plot(x,y_GS,"Silver", marker='o',label='GS',linewidth=3)
plt.plot(x,y_HC,"Gray",marker='x',label='MWST-HC',linewidth=3)
plt.plot(x,y_GES,"DimGray", marker='>',label='MWST-GES',linewidth=3)

plt.legend(fontsize= 14)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('迭代次数/次',fontsize= 12) #X轴标签
plt.ylabel("先验网络最优结构BIC评分平均值",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\water_平均1.jpg',dpi = 100)

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
x=[0,15,35,40,55,
   60,65,70,75,
   80,85,90,95,100,
   110,120,130,140,150,
   160,170,180,190,200,
   230,250, 270,300,320,350,370,400]


y_EMGA=[-10343,-8473,-7963,-7469,-7231,
        -6873,-6653,-6318,-6053,
        -5856,-5673,-5398,-5290,-5193,
        -5100,-5096,-5073,-5053,-5033,
        -5003,-5000,-5001,-5002,-5002,
        -5002,-5001,-5002,-5003,-5003,-5002,-5003,-5002]


y_MMHC=[-13003,-11038,-10341,-9970,-9764,
        -9501,-9384,-9038,-8931,-8745,
        -8699,-8539,-8451,-8303,-8199,
        -8056,-7994,-7854,-7697,
        -7655,-7640,-7623,-7608,-7560,
        -7340,-7340,-7340,-7340,-7340,-7340,-7340,-7340]

y_GS=  [-11683,-10568,-9967,-9708,-9541,
        -9237,-9034,-8964,-8674,
        -8423,-8105,-8098,-8056,-7867,
        -7539,-7166,-7080,-6941,-6807,
        -6748,-6698,-6659, -6568,-6530,
        -6512,-6509,-6487,-6487,-6487,-6487,-6489,-6485]

y_HC= [-11356,-10357,-9946,-9603,-9451,
       -9183,-9061,-8852,-8768,
       -8541, -8498,-8301,-8195,-7864,
       -7558,-7085,-6874,-6537,-6239,
       -5984,-5857,-5769,-5770,-5769,
       -5768,-5769,-5770,-5768,-5769,-5770,-5769,-5768]


y_GES=[-11284,-10853,-9853,-9313,-9023,
       -8953,-8594,-8042,-7943,
       -7843,-7643,-7452,-7249,-7013,
       -6983,-6803,-6735,-6698,-6598,
       -6456,-6320,-6234,-6103,-6000,
      -5981,-5980,-5981,-5982,-5980,-5981,-5980,-5981]

plt.plot(x, y_EMGA,'black',label='IMGA-DBN',linewidth=4)
plt.plot(x,y_MMHC,"Gainsboro",marker='|',label='DMMHC',linewidth=3)
plt.plot(x,y_GS,"Silver", marker='o',label='GS',linewidth=3)
plt.plot(x,y_HC,"Gray",marker='x',label='MWST-HC',linewidth=3)
plt.plot(x,y_GES,"DimGray", marker='>',label='MWST-GES',linewidth=3)

plt.legend(fontsize= 14)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('迭代次数/次',fontsize= 12) #X轴标签
plt.ylabel("转移网络最优结构BIC评分平均值",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\water_平均2.jpg',dpi = 100)

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
x=[0,15,35,
   60,65,70,75,
   80,85,90,95,100,
   
   160,170,180,190,200,
   230,250, 270,300,320,350,370,400]


y_EMGA=[-10343,-8473,-7963,
        -6873,-6653,-6318,-6053,
        -5856,-5673,-5398,-5290,-5193,
        
        -5003,-5000,-5001,-5002,-5002,
        -5002,-5001,-5002,-5003,-5003,-5002,-5003,-5002]


y_MMHC=[-11003,-9315,-9041,
        -8699,-8539,-8451,-8303,
        -8199,-8056,-7994,-7854,-7697,
        
        -7378,-7363,-7355,-7350,-7348,
        -7340,-7340,-7340,-7340,-7340,-7340,-7340,-7340]

y_GS=  [-10683,-9908,-8964,
        -8899,-8642,-8602,-8505,
        -8550,-8056,-7539,-7066,-6880,
       
        -6609, -6588,-6568,-6549,-6530,
        -6512,-6509,-6487,-6487,-6487,-6487,-6489,-6485]

#y_HC= [-4779,-3931,-3408,-3245,-3088,
       -2968,-2943,-2929,-2898,
       -2888,-2867,-2845,-2820,-2800,
       -2799,-2796,-2755,-2747,-2741,
       -2737,-2728,-2736,-2727,-2738,
       -2737,-2728,-2736,-2727,-2738,-2736,-2727,-2738]


#y_GES=[-4840,-4003,-3388,-3298,-3201,
       -3077,-2987,-2947,-2922,
       -2917,-2900,-2888,-2867,-2850,
       -2838,-2811,-2803,-2795,-2763,
       -2754,-2747,-2731,-2729,-2707,
      -2692,-2693,-2693,-2693,-2694,-2692,-2693,-2693,]

plt.plot(x, y_EMGA,'black',label='IMGA-DBN',linewidth=4)
plt.plot(x,y_MMHC,"Gainsboro",marker='|',label='DMMHC',linewidth=3)
plt.plot(x,y_GS,"Silver", marker='o',label='GS',linewidth=3)
#plt.plot(x,y_HC,"Gray",marker='x',label='MWST-HC',linewidth=3)
#plt.plot(x,y_GES,"DimGray", marker='>',label='MWST-GES',linewidth=3)

plt.legend(fontsize= 14)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('迭代次数/次',fontsize= 12) #X轴标签
plt.ylabel("先验网络最优结构BIC评分平均值",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\water_平均2.jpg',dpi = 100)
# Out:
#   File "<ipython-input-38-4d7fb1d7f13a>", line 34
#     -2968,-2943,-2929,-2898,
#     ^
# IndentationError: unexpected indent

# %%
from scipy import interpolate

fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
x=[0,15,35,40,
   55,60,65,70,75,
   80,85,90,95,100,
   110,120,130,140,150,
   160,170,180,190,200,
   230,250, 270,300,320,350,370,400]
y_EMGA=[-4770,-3503,-3299,-3013,
        -2813,-2798,-2783,-2736,-2709,
        -2695,-2690,-2689,-2687,-2688,
        -2689,-2686,-2688,-2685,-2686,
        -2689,-2686,-2688,-2685,-2686,
        -2689,-2686,-2688,-2685,-2686,-2685,-2686,-2688]
y_MMHC=[-5000,-4873,-4583,-4472,-4410,
        -4323,-4287,-4255,-4163,
        -4137,-4107,-4079,-4047,-4025,
        -4012,-4006,-3995,-3990,-3989,
        -3980,-3982, -3970,-3958,-3920,
        -3898,-3889, -3884,-3881,-3885,-3880,-3881,-3880]
y_GS=  [-4789,-4031,-3673,-3401,
        -3203,-3057,-2999,-2986,-2974,
        -2969,-2960,-2957,-2947,-2940,
        -2930,-2918,-2904,-2893,-2887,
        -2869, -2853,-2844,-2825,-2820,
        -2810,-2803,-2798,-2799,-2798,-2799,-2799,-2798]

y_HC= [-4779,-3631,-3488,-3145,
       -2990,-2968,-2943,-2929,-2898,
       -2888,-2867,-2845,-2820,-2800,
       -2799,-2796,-2755,-2747,-2741,
       -2737,-2728,-2736,-2727,-2738,
       -2737,-2728,-2736,-2727,-2738,-2736,-2727,-2738]


#plt.plot(x, y_EMGA, marker='o',color='black',label='IMGA-DBN')
#plt.plot(x, y, marker='*',color='black',ls='-.',label='DMMHC')
#plt.plot(x, y_GS, marker='+',color='black',ls='--',label='GS')


#实现函数
#func = interpolate.interp1d(x,y,kind='cubic')
 
#利用xnew和func函数生成ynew,xnew数量等于ynew数量
#ynew = func(x)
 
# 原始折线
#plt.plot(x, y, "black", linewidth=5,label='DMMHC')
 
#平滑处理后曲线
plt.plot(x, y_EMGA, 'black',label='IMGA-DBN',linewidth=4)
plt.plot(x,y_MMHC, "Gainsboro",label='DMMHC',ls='-.',linewidth=4)
plt.plot(x,y_GS, "Silver",label='GS',ls='--',linewidth=4)
plt.plot(x,y_HC, "Gray",label='MWST_HC',linewidth=4)
plt.legend(fontsize= 14)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate
 
#设置距离
x =np.array([0, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 70, 8, 9,10])
 
#设置相似度
y =np.array([0.8579087793827057, 0.8079087793827057, 0.7679087793827057, 0.679087793827057,
    0.5579087793827057, 0.4579087793827057, 0.3079087793827057, 0.3009087793827057,
    0.2579087793827057, 0.2009087793827057, 0.1999087793827057, 0.1579087793827057,
    0.0099087793827057, 0.0079087793827057, 0.0069087793827057, 0.0019087793827057,
    0.0000087793827057])
 
#插值法之后的x轴值，表示从0到10间距为0.5的200个数
xnew =np.arange(0,10,0.1)
 
#实现函数
func = interpolate.interp1d(x,y,kind='cubic')
 
#利用xnew和func函数生成ynew,xnew数量等于ynew数量
ynew = func(xnew)
 
# 原始折线
plt.plot(x, y, "r", linewidth=1)
 
#平滑处理后曲线
plt.plot(xnew,ynew)
#设置x,y轴代表意思
plt.xlabel("The distance between POI  and user(km)")
plt.ylabel("probability")
#设置标题
plt.title("The content similarity of different distance")
#设置x,y轴的坐标范围
plt.xlim(0,10,8)
plt.ylim(0,1)
 
plt.show()

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
# Asia网络的运行时间的平均值和标准差
x=[1000,2500,5000,10000]
y_EMGA=[50,70,150,597] #第1个纵坐标
std1=[14.9,15,17,18]
y_DMMHC=[100,126.2,419,860] #第2个纵坐标
std2=[30.3,52.5,70,84]
y_GS=[200,270,922,1678]#第3个纵坐标
std3=[56,80,120,100]
x=np.arange(len(x))#首先用第一个的长度作为横坐标
width=0.25 #设置柱与柱之间的宽度

error_params=dict(elinewidth=3,ecolor='black',capsize=5)#设置误差标记参数
plt.bar(x,y_EMGA,width,color='k',label='IMGA-DBN',yerr=std1,error_kw=error_params)
plt.bar(x+width,y_DMMHC,width,color='gray',label='DMMHC',yerr=std2,error_kw=error_params)
plt.bar(x+2*width,y_GS,width,color='silver',label='GS',yerr=std3,error_kw=error_params)
plt.legend(fontsize= 14)  # 让图例生效
plt.xticks(x+width,['1000','2500','5000','10000'],fontsize= 12)
plt.yticks(fontsize= 12)

 
plt.margins(0)
plt.subplots_adjust(bottom=0.10)
plt.xlabel('样本量',fontsize= 12) #X轴标签
plt.ylabel("运行时间/s",fontsize= 12) #Y轴标签
# plt.title("A simple plot") #标题
plt.savefig('D:\Entertainment\jyputer\yunxing.jpg',dpi = 900)

# %%
# Asia网络的运行时间的平均值和标准差
x=[1000,2500,5000,10000]
y_EMGA=[50,70,150,597] #第1个纵坐标
std1=[14.9,15,17,18]
y_DMMHC=[100,126.2,419,860] #第2个纵坐标
std2=[30.3,52.5,70,84]
y_GS=[200,270,922,1678]#第3个纵坐标
std3=[56,80,120,100]
x=np.arange(len(x))#首先用第一个的长度作为横坐标
width=0.25 #设置柱与柱之间的宽度

error_params=dict(elinewidth=3,ecolor='black',capsize=5)#设置误差标记参数
plt.bar(x,y_EMGA,width,color='k',label='IMGA-DBN',yerr=std1,error_kw=error_params)
plt.bar(x+width,y_DMMHC,width,color='gray',label='DMMHC',yerr=std2,error_kw=error_params)
plt.bar(x+2*width,y_GS,width,color='silver',label='GS',yerr=std3,error_kw=error_params)
plt.legend(fontsize= 14)  # 让图例生效
plt.xticks(x+width,['1000','2500','5000','10000'],fontsize= 12)
plt.yticks(fontsize= 12)

 
plt.margins(0)
plt.subplots_adjust(bottom=0.10)
plt.xlabel('样本量',fontsize= 12) #X轴标签
plt.ylabel("运行时间/s",fontsize= 12) #Y轴标签
# plt.title("A simple plot") #标题
plt.savefig('D:\Entertainment\jyputer\yunxing.jpg',dpi = 900)

# %%
series1=np.array([2,3,4,5])
series2=np.array([1,2,3,4])
series3=np.array([1,4,2,1])
index=np.arange(4)
plt.axis([0,4,0,15])
plt.bar(index+0.5,series1,color='w',hatch='+')
plt.bar(index+0.5,series2,color='w',hatch='//',bottom=series1)
plt.bar(index+0.5,series3,color='w',hatch='\\\\',bottom=(series1+series2))
# 同一符号出现的次数越多，则形成的阴影的线条越密集
plt.xticks(index+0.5,['Jan','Feb','Mar','Apr'])
plt.show()

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
# 转移网准确度
l=range(0,12000,1000)
x=(250,500,1000)
y_3=[-1.30,-1.17,-1.01]
y_4=[-1.15,-1.02,-0.98]
y_5=[-1.09,-0.99,-0.95]
y_6=[-0.96,-0.92,-0.87]
plt.plot(x, y_3, marker='o',color='black',label='HD=3')
plt.plot(x, y_4, marker='*',color='black',label='HD=4')
plt.plot(x, y_5, marker='+',color='black',label='HD=5')
plt.plot(x, y_6,color='black',label='HD=6')
plt.legend(fontsize= 14)  # 让图例生效
plt.text(400,-1.27, "δ=10", size = 15, alpha = 1)
plt.margins(0)
plt.subplots_adjust(bottom=0.10)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('序列数目',fontsize= 12) #X轴标签
plt.ylabel("平均对数损失",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\loss1.jpg',dpi = 900)
#plt.xticks(['250','500','1000'])
# plt.title("A simple plot") #标题

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
x=(250,500,1000)
y_3=[-1.03,-1.00,-0.98]
y_4=[-0.97,-0.95,-0.93]
y_5=[-0.96,-0.90,-0.89]
y_6=[-0.94,-0.88,-0.85]
plt.plot(x, y_3, marker='o',color='black',label='HD=3')
plt.plot(x, y_4, marker='*',color='black',label='HD=4')
plt.plot(x, y_5, marker='+',color='black',label='HD=5')
plt.plot(x, y_6,color='black',label='HD=6')
plt.legend(bbox_to_anchor=(0.96, 0.31),fontsize= 12)  # 让图例生效
plt.text(400,-1.02, "δ=15", size = 15, alpha = 1)
plt.margins(0)
plt.subplots_adjust(bottom=0.10)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('序列数目',fontsize= 12) #X轴标签
plt.ylabel("平均对数损失",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\loss2.jpg',dpi = 900)
#plt.xticks(['250','500','1000'])

# %%
fig=plt.figure(figsize=(7,5))
fig.set(alpha=0.2)
x=(250,500,1000)
y_3=[-1.00,-0.95,-0.91]
y_4=[-0.93,-0.92,-0.90]
y_5=[-0.92,-0.90,-0.90]
y_6=[-0.91,-0.89,-0.87]
plt.plot(x, y_3, marker='o',color='black',label='HD=3')
plt.plot(x, y_4, marker='*',color='black',label='HD=4')
plt.plot(x, y_5, marker='+',color='black',label='HD=5')
plt.plot(x, y_6,color='black',label='HD=6')
plt.legend(bbox_to_anchor=(0.985, 0.31),fontsize= 12)  # 让图例生效
plt.text(400,-0.99, "δ=20", size = 15, alpha = 1)
plt.margins(0)
plt.subplots_adjust(bottom=0.10)
plt.xticks(fontsize= 12)
plt.yticks(fontsize= 12)
plt.xlabel('序列数目',fontsize= 12) #X轴标签
plt.ylabel("平均对数损失",fontsize= 12) #Y轴标签
plt.savefig('D:\Entertainment\jyputer\loss3.jpg',dpi = 900)
